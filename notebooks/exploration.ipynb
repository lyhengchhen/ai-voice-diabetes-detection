# %%
import sys

# !{sys.executable} -m pip install xgboost matplotlib seaborn statsmodels scikit-learn
# Out:
# zsh:1: permission denied: /Users/jeldy/AI_voice_detection_for_diabetes

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, balanced_accuracy_score, confusion_matrix
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load female and male datasets
female_data = pd.read_pickle('data/vocadiab/vocadiab_females_dataset.pkl')
male_data = pd.read_pickle('data/vocadiab/vocadiab_males_dataset.pkl')
print("Female data shape:", female_data.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load female and male datasets
# ----> 2 female_data = pd.read_pickle('data/vocadiab/vocadiab_females_dataset.pkl')
#       3 male_data = pd.read_pickle('data/vocadiab/vocadiab_males_dataset.pkl')
#       4 print("Female data shape:", female_data.shape)
#
# File ~/AI_voice_detection_for_diabetes /.venv/lib/python3.14/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)    182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
# ...

# %%
# Load female and male datasets
female_data = pd.read_pickle('data/vocadiab/vocadiab_females_dataset.pkl')
male_data = pd.read_pickle('data/vocadiab/vocadiab_males_dataset.pkl')

print("Female data shape:", female_data.shape)
print("Male data shape:", male_data.shape)

female_data.head()

# %%
# Extract embeddings (they are stored as lists/arrays)
X_female = np.array(female_data['byols_embeddings'].tolist())  # Convert to numpy array
y_female = female_data['ADA_score'].values              # 1 = diabetes, 0 = no diabetes

# Add age and BMI as extra features (helps a lot!)
X_female = np.hstack([X_female, female_data[['age', 'bmi']].values])

print("Features shape:", X_female.shape)
print("Labels distribution:\n", pd.Series(y_female).value_counts())

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_female, y_female, test_size=0.2, random_state=42, stratify=y_female
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    random_state=42,
    n_estimators=100
)

model.fit(X_train_scaled, y_train)

# Predict
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %%
# Predict on test set
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Print results
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# %%
# Predictions
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Balanced Accuracy:", balanced_accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix Heatmap
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['No Diabetes', 'Diabetes'], 
            yticklabels=['No Diabetes', 'Diabetes'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, balanced_accuracy_score, confusion_matrix
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load female and male datasets
female_data = pd.read_pickle('data/vocadiab/vocadiab_females_dataset.pkl')
male_data = pd.read_pickle('data/vocadiab/vocadiab_males_dataset.pkl')

print("Female data shape:", female_data.shape)
print("Male data shape:", male_data.shape)

female_data.head()

# %%
# Extract embeddings (they are stored as lists/arrays)
X_female = np.array(female_data['byols_embeddings'].tolist())  # Convert to numpy array
y_female = female_data['ADA_score'].values              # 1 = diabetes, 0 = no diabetes

# Add age and BMI as extra features (helps a lot!)
X_female = np.hstack([X_female, female_data[['age', 'bmi']].values])

print("Features shape:", X_female.shape)
print("Labels distribution:\n", pd.Series(y_female).value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Extract embeddings (they are stored as lists/arrays)
# ----> 2 X_female = np.array(female_data['byols_embeddings'].tolist())  # Convert to numpy array
#       3 y_female = female_data['ADA_score'].values              # 1 = diabetes, 0 = no diabetes
#       5 # Add age and BMI as extra features (helps a lot!)
#
# NameError: name 'female_data' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_female, y_female, test_size=0.2, random_state=42, stratify=y_female
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 X_train, X_test, y_train, y_test = train_test_split(
# ----> 2     X_female, y_female, test_size=0.2, random_state=42, stratify=y_female
#       3 )
#       5 scaler = StandardScaler()
#       6 X_train_scaled = scaler.fit_transform(X_train)
#
# NameError: name 'X_female' is not defined

# %%
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    random_state=42,
    n_estimators=100
)

model.fit(X_train_scaled, y_train)

# Predict
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       1 model = xgb.XGBClassifier(
#       2     objective='binary:logistic',
#       3     eval_metric='auc',
#       4     random_state=42,
#       5     n_estimators=100
#       6 )
# ----> 8 model.fit(X_train_scaled, y_train)
#      10 # Predict
#      11 y_pred = model.predict(X_test_scaled)
#
# NameError: name 'X_train_scaled' is not defined

# %%
# Predict on test set
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Print results
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# %%
# Predictions
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Balanced Accuracy:", balanced_accuracy_score(y_test, y_pred))
print("AUC Score:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix Heatmap
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['No Diabetes', 'Diabetes'], 
            yticklabels=['No Diabetes', 'Diabetes'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
